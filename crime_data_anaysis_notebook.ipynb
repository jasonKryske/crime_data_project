# %% [markdown]
# # 2020 Crime Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
crimeDF = pd.read_csv('Crime_Data_from_2020_to_Present.csv')

# %% [markdown]
# # Exploratory Analysis

# %%
crimeDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974477 entries, 0 to 974476
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           974477 non-null  int64
#  1   Date Rptd       974477 non-null  object
#  2   DATE OCC        974477 non-null  object
#  3   TIME OCC        974477 non-null  int64
#  4   AREA            974477 non-null  int64
#  5   AREA NAME       974477 non-null  object
#  6   Rpt Dist No     974477 non-null  int64
#  7   Part 1-2        974477 non-null  int64
#  8   Crm Cd          974477 non-null  int64
#  9   Crm Cd Desc     974477 non-null  object
#  10  Mocodes         831701 non-null  object
#  11  Vict Age        974477 non-null  int64
#  12  Vict Sex        838474 non-null  object
#  13  Vict Descent    838464 non-null  object
#  14  Premis Cd       974463 non-null  float64
#  15  Premis Desc     973893 non-null  object
# ...

# %%
crimeDF.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
# Visualizes the count and  proportion of null values in a given field
msno.bar(crimeDF)
# Out:
# <AxesSubplot:>

# %%
crimeDF.nunique()
# Out:
# DR_NO             974477
# Date Rptd           1707
# DATE OCC            1707
# TIME OCC            1439
# AREA                  21
# AREA NAME             21
# Rpt Dist No         1209
# Part 1-2               2
# Crm Cd               139
# Crm Cd Desc          139
# Mocodes           308907
# Vict Age             104
# Vict Sex               5
# Vict Descent          20
# Premis Cd            314
# Premis Desc          306
# Weapon Used Cd        79
# Weapon Desc           79
# Status                 6
# Status Desc            6
# Crm Cd 1             141
# Crm Cd 2             126
# Crm Cd 3              37
# Crm Cd 4               6
# LOCATION           66165
# Cross Street       10294
# LAT                 5424
# LON                 4980
# dtype: int64

# %%
crimeDF.apply(pd.unique)
# Out:
# DR_NO             [190326475, 200106753, 200320258, 200907217, 2...
# Date Rptd         [03/01/2020 12:00:00 AM, 02/09/2020 12:00:00 A...
# DATE OCC          [03/01/2020 12:00:00 AM, 02/08/2020 12:00:00 A...
# TIME OCC          [2130, 1800, 1700, 2037, 1200, 2300, 900, 1110...
# AREA              [7, 1, 3, 9, 6, 18, 13, 19, 2, 10, 8, 20, 4, 2...
# AREA NAME         [Wilshire, Central, Southwest, Van Nuys, Holly...
# Rpt Dist No       [784, 182, 356, 964, 666, 1826, 303, 1375, 197...
# Part 1-2                                                     [1, 2]
# Crm Cd            [510, 330, 480, 343, 354, 624, 821, 812, 230, ...
# Crm Cd Desc       [VEHICLE - STOLEN, BURGLARY FROM VEHICLE, BIKE...
# Mocodes           [nan, 1822 1402 0344, 0344 1251, 0325 1501, 18...
# Vict Age          [0, 47, 19, 28, 41, 25, 27, 24, 26, 8, 7, 56, ...
# Vict Sex                                       [M, X, F, nan, H, -]
# Vict Descent      [O, X, H, B, W, nan, A, K, C, J, F, I, V, S, P...
# ...
